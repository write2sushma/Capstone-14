# %% [markdown]
# # Capstone Team 14

# %%
# os = operating system
import os
import pandas as pd
import matplotlib.pyplot as plt

print("Path at terminal when executing this file")
print(os.getcwd())
# Out:
# Path at terminal when executing this file
# C:\Users\sai.hin.sin\Documents\Pyladiesams\Bootcamp-Data-Analysis-beginner-apr-may2020\lessons

# %%
path_whr2017 = "data/coronavirusdataset/whr2017.csv"
path_whr2018 = "data/coronavirusdataset/whr2018.csv"

whr2017 = pd.read_csv(path_whr2017)
whr2018 = pd.read_csv(path_whr2018)

# %%
# within () you provide a number how many records will be displayed
whr2017.head(500)
# Out:
#                       Country  Happiness.Rank  Happiness.Score  Whisker.high  \
# 0                      Norway               1            7.537      7.594445
# 1                     Denmark               2            7.522      7.581728
# 2                     Iceland               3            7.504      7.622030
# 3                 Switzerland               4            7.494      7.561772
# 4                     Finland               5            7.469      7.527542
# ..                        ...             ...              ...           ...
# 150                    Rwanda             151            3.471      3.543030
# 151                     Syria             152            3.462      3.663669
# 152                  Tanzania             153            3.349      3.461430
# 153                   Burundi             154            2.905      3.074690
# 154  Central African Republic             155            2.693      2.864884
#
# ...

# %%
whr2018.head(500)
# Out:
#      Overall rank                   Country  Score  GDP per capita  \
# 0               1                   Finland  7.632           1.305
# 1               2                    Norway  7.594           1.456
# 2               3                   Denmark  7.555           1.351
# 3               4                   Iceland  7.495           1.343
# 4               5               Switzerland  7.487           1.420
# ..            ...                       ...    ...             ...
# 151           152                     Yemen  3.355           0.442
# 152           153                  Tanzania  3.303           0.455
# 153           154               South Sudan  3.254           0.337
# 154           155  Central African Republic  3.083           0.024
# 155           156                   Burundi  2.905           0.091
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 0             1.592                    0.874                         0.681
# ...

# %%
merge = whr2017.merge(whr2018, on = ["Country"])

# %%
merge.head(500)
# Out:
#                       Country  Happiness.Rank  Happiness.Score  Whisker.high  \
# 0                      Norway               1            7.537      7.594445
# 1                     Denmark               2            7.522      7.581728
# 2                     Iceland               3            7.504      7.622030
# 3                 Switzerland               4            7.494      7.561772
# 4                     Finland               5            7.469      7.527542
# ..                        ...             ...              ...           ...
# 146                    Rwanda             151            3.471      3.543030
# 147                     Syria             152            3.462      3.663669
# 148                  Tanzania             153            3.349      3.461430
# 149                   Burundi             154            2.905      3.074690
# 150  Central African Republic             155            2.693      2.864884
#
# ...

# %%
# The happier you are, the longer you will live
merge.plot(kind='scatter',x='Happiness.Score',y='Healthy life expectancy',color='red')
plt.show()
